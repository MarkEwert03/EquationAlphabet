# %%
from src.generate import generate_all_equations

# %%
generate_all_equations(2)
# Out:
# [('A', '+', 'A', 'A'),
#  ('A', '*', 'A', 'A'),
#  ('A', '+', 'A', 'B'),
#  ('A', '*', 'A', 'B'),
#  ('A', '+', 'B', 'A'),
#  ('A', '*', 'B', 'A'),
#  ('A', '+', 'B', 'B'),
#  ('A', '*', 'B', 'B'),
#  ('B', '+', 'A', 'A'),
#  ('B', '*', 'A', 'A'),
#  ('B', '+', 'A', 'B'),
#  ('B', '*', 'A', 'B'),
#  ('B', '+', 'B', 'A'),
#  ('B', '*', 'B', 'A'),
#  ('B', '+', 'B', 'B'),
#  ('B', '*', 'B', 'B')]

# %%
len(generate_all_equations(2))
# Out:
# 16
